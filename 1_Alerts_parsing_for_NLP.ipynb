# %% [markdown]
# ## Alerts Data Parsing
#
# Parse all the alerts data of multiple sources downloaded from pagerduty and merge them to form an alerts dataset.
# Finally create a dataset with the columns as alert identifier, alert id, incident number, affected services, alert condition, etc.
#
# Use alerts data from the following sources in the final dataset:
# 1. Adobe Sign SRE
# 2. Adobe Sign DBA
# 3. Adobe Sign FedRAMP SRE
# 4. Splunk
# 5. Sign - Pingdom
# 6. Datadog-Prod
# 7. eda-alerts-prod
# 6. Sign MS Techops Oncall

# %%
import os
import json
import pandas as pd

# %%
directory = './Alerts_data/pagerduty_data'

# %%
final_json = []
for alert_file in os.listdir(directory):
    if alert_file == '.ipynb_checkpoints':
        continue
    else:
        with open(directory + '/' + alert_file, 'r') as f:
            data = json.load(f)
        final_json += data['incidents']
with open('./Alerts_data/all_alerts.json', 'w') as f:
    json.dump(final_json,f)

# %%
f = json.load(open('./Alerts_data/all_alerts.json', 'r'))
df_normalised = pd.json_normalize(f)

# %%
t = pd.to_datetime('2020-10-01')

# %%
df_normalised[df_normalised['created_at'] > t.strftime('%Y-%m-%dT%XZ')]['created_at'].sort_values()
# Out:
# 39468    2020-10-01T00:20:19Z
# 39467    2020-10-01T01:51:27Z
# 39466    2020-10-01T02:06:25Z
# 31244    2020-10-01T03:55:19Z
# 39465    2020-10-01T04:09:19Z
#                  ...
# 1219     2022-07-19T07:44:22Z
# 1218     2022-07-19T07:47:25Z
# 1217     2022-07-19T08:28:51Z
# 1216     2022-07-19T09:11:17Z
# 1200     2022-07-19T09:38:04Z
# Name: created_at, Length: 43833, dtype: object

# %%
print('total', len(df_normalised['incident_number']), 'alerts')
# Out:
# total 58255 alerts

# %%
services = list(set(list(df_normalised['service.summary'])))

# %%
services
# Out:
# ['DC SRE Manager On-Call',
#  'DCSRE-Manager-OnCall-Escalation',
#  'eda-alerts-stage',
#  'eda-alerts-dev',
#  'Adobe Sign Dev',
#  'DataDog-Stage-Pythian',
#  'Adobe Sign FedRAMP SRE',
#  'Cortex-AdobeSign',
#  'Adobe Sign Splunk',
#  'Adobe Sign DBA',
#  'Sign - Pingdom',
#  'Splunk',
#  'Datadog-Prod-Pythian',
#  'Sign MS Techops Oncall',
#  'eda-alerts-prod',
#  'Hystrix-Dev',
#  'Datadog-Prod',
#  'Adobe Sign SRE',
#  'Sean Test',
#  'CSO Launch']

# %%
service_ab = ['sre', 'dcsreoc', 'cso', 'dba' , 'fsre' , 'splunk' , 'ddg' , 'dcsreoce' , 'pgdm' , 'eda' , 'smto' , 'dev']
service_dict = {
    'Adobe Sign SRE' : 'sre',
    'DC SRE Manager On-Call' : 'dcsreoc',
    'CSO Launch' : 'cso',
    'Adobe Sign DBA' : 'dba',
    'Adobe Sign FedRAMP SRE' : 'fsre',
    'Splunk' : 'splunk',
    'Adobe Sign Splunk' : 'splunk',
    'Datadog-Prod' : 'ddg',
    'DCSRE-Manager-OnCall-Escalation' : 'dcsreoce',
    'Sign - Pingdom' : 'pgdm',
    'eda-alerts-prod' : 'eda',
    'Sign MS Techops Oncall' : 'smto',
    'Adobe Sign Dev' : 'dev'
}

# %%
df_dict = {}
for service in service_dict:
    print(service)
    df_dict[service_dict[service]] = df_normalised[df_normalised['service.summary'] == service].astype(str)
# Out:
# Adobe Sign SRE
# DC SRE Manager On-Call
# CSO Launch
# Adobe Sign DBA
# Adobe Sign FedRAMP SRE
# Splunk
# Adobe Sign Splunk
# Datadog-Prod
# DCSRE-Manager-OnCall-Escalation
# Sign - Pingdom
# eda-alerts-prod
# Sign MS Techops Oncall
# Adobe Sign Dev

# %%
parsed_dict = {}

# %% [markdown]
# ## SRE

# %%
parsed_dict['sre'] = {'incident_number':[], 'created_at':[], 'alert_identifier':[], 'node_name':[], 'service':[], 'metric_value':[], 'description':[], 'alert_condition':[]}
for i, inc_num in enumerate(df_dict['sre']['incident_number'].values):
    # print(i)
    temp = {'incident_number':None, 'created_at':None, 'alert_identifier':None, 'node_name':None, 'service':None, 'metric_value':None, 'description':None, 'alert_condition':None}
    try:
        val = ('alertname' not in (df_dict['sre']['first_trigger_log_entry.channel.cef_details.details.firing'].iloc[i].split('\n')[1].split('=')[0].lower()))
        if (not val):
            firing = df_dict['sre']['first_trigger_log_entry.channel.cef_details.details.firing'].iloc[i].split('\n')
            temp['incident_number'] = inc_num
            # print('hey')
            temp['created_at'] = df_dict['sre']['created_at'].iloc[i]
            # print('ho')
            temp['alert_identifier'] = firing[1].split('=')[1].lower()
            temp['node_name'] = temp['alert_identifier']
            temp['service'] = df_dict['sre']['first_trigger_log_entry.service.summary'].iloc[i]
            count = 0
            for j in firing:
                if 'metric_value' in j and count < 2:
                    count += 1
                    temp['metric_value'] = j.split('=')[1]
                if 'alertcondition' in j and count < 2:
                    count += 1
                    temp['alert_condition'] = j.split('=')[1]
            temp['description'] = df_dict['sre']['first_trigger_log_entry.event_details.description'].iloc[i]
    except:
        print(i, inc_num, df_dict['sre']['title'].iloc[i].lower())
    flag = True
    for e in temp:
        if temp[e] is None:
            flag = False
            break
    if flag:
        for e in temp:
            parsed_dict['sre'][e].append(temp[e])
# Out:
# 1813 509370 join active cso
# 3060 1448915 join cso 17662 - adobe sign europe 1 - critical systems notification
# 3799 337213 please join preemptive cso
# 6512 144999 test mail. please ignore.
# 7326 589759 sorry testing - ack in slack and resolve
# 7733 13843 testing 123
# 8982 406435 cso 11993 - cemt na3 (azure) - critical systems notification
# 9088 740175 fw: cso 15663 - adobe sign europe 1 - critical systems notification
# 9538 1413640 fw: cso 17536 - default services - critical systems notification
# 10000 517801 please join active cso
# 11360 932026 serving cupcakes for document cloud - adobe sign - cupcake
# 16268 414735 re: cso 12041 - document cloud - adobe sign - critical systems notification
# 20920 765361 this is a critical systems notification for eoa migration service.

# %%
try:
    pd.DataFrame(parsed_dict['sre'])
    print('Parsing did well')
    print('Parsed', len(parsed_dict['sre']['incident_number']), 'alerts')
except:
    print('Not all arrays of same size')
# Out:
# Parsing did well
# Parsed 21510 alerts

# %% [markdown]
# ## DBA

# %%
parsed_dict['dba'] = {'incident_number':[], 'created_at':[], 'alert_identifier':[], 'node_name':[], 'service':[], 'metric_value':[], 'description':[], 'alert_condition':[]}
for i, inc_num in enumerate(df_dict['dba']['incident_number'].values):
    # print(i)
    temp = {'incident_number':None, 'created_at':None, 'alert_identifier':None, 'node_name':None, 'service':None, 'metric_value':None, 'description':None, 'alert_condition':None}
    try:
        val = ('alertname' not in (df_dict['dba']['first_trigger_log_entry.channel.cef_details.details.firing'].iloc[i].split('\n')[1].split('=')[0].lower()))
        if (not val):
            temp['service'] = df_dict['dba']['first_trigger_log_entry.service.summary'].iloc[i]
            temp['description'] = df_dict['dba']['first_trigger_log_entry.event_details.description'].iloc[i]
            firing = df_dict['dba']['first_trigger_log_entry.channel.cef_details.details.firing'].iloc[i].split('\n')
            temp['incident_number'] = (inc_num)
            # print('hey')
            temp['created_at'] = (df_dict['dba']['created_at'].iloc[i])
            # print('ho')
            temp['alert_identifier'] = (df_dict['dba']['first_trigger_log_entry.channel.cef_details.details.firing'].iloc[i].split('\n')[1].split('=')[1].lower())
            temp['node_name'] = (temp['alert_identifier'])
            count = 0
            flag1 = True
            flag2 = True
            for j in firing:
                if 'metric_value' in j and count < 2:
                    count += 1
                    temp['metric_value'] = (j.split('=')[1])
                    flag1 = False
                if 'alertcondition' in j and count < 2:
                    count += 1
                    temp['alert_condition'] = (j.split('=')[1])
                    flag2 = False
            if flag1:
                temp['metric_value'] = ('NA')
            if flag2:
                temp['alert_condition'] = ('NA')
                
    except Exception as e:
        # print(i, inc_num, df_dict['dba']['title'].iloc[i].lower())
        if ('prod' in df_dict['dba']['title'].iloc[i].lower()):
            temp['incident_number'] = (inc_num)
            temp['created_at'] = (df_dict['dba']['created_at'].iloc[i])
            temp['service'] = (df_dict['dba']['first_trigger_log_entry.service.summary'].iloc[i])
            temp['description'] = (df_dict['dba']['first_trigger_log_entry.event_details.description'].iloc[i])
            try:
                ls = list(map(str.strip,df_dict['dba']['title'].iloc[i].split('-')))
                ind = ls.index('prod') + 1
                rem = ''
                for j in range(len(ls)):
                    rem += ls[j] + ' '
                temp['alert_identifier'] = (rem)
            except:
                print(i,inc_num, 'prod nhi mila')
            
            if (' on ' not in temp['alert_identifier'] and ' for ' not in temp['alert_identifier']):
                print(i,inc_num, 'none', temp['alert_identifier'], df_dict['dba']['title'].iloc[i])
            else:
                if(' on ' in temp['alert_identifier']):
                    ind = temp['alert_identifier'].find(' on ')
                    temp['node_name'] = (temp['alert_identifier'][:ind])
                else:
                    if(' for ' in temp['alert_identifier']):
                        ind = temp['alert_identifier'].find(' for ')
                        temp['node_name'] = (temp['alert_identifier'][:ind])
                    else:
                        temp['node_name'] = (temp['alert_identifier'])
            metric_text = df_dict['dba']['first_trigger_log_entry.channel.details.body'].iloc[i].lower().split('\n')
            for j in metric_text:
                if 'metric value' in j:
                    temp['metric_value'] = (j.split(':')[1])
            temp['alert_condition'] = (metric_text[2])
            # print(i, temp['alert_identifier'], temp['node_name'])
    flag = True
    for e in temp:
        if temp[e] is None:
            flag = False
            break
    if flag:
        for e in temp:
            parsed_dict['dba'][e].append(temp[e])

# %%
try:
    pd.DataFrame(parsed_dict['dba'])
    print('Parsing did well')
    print('Parsed', len(parsed_dict['dba']['incident_number']), 'alerts')
except:
    print('Not all arrays of same size')
# Out:
# Parsing did well
# Parsed 9416 alerts

# %% [markdown]
# ## FSRE

# %%
parsed_dict['fsre'] = {'incident_number':[], 'created_at':[], 'alert_identifier':[], 'node_name':[], 'service':[], 'metric_value':[], 'description':[], 'alert_condition':[]}
for i, inc_num in enumerate(df_dict['fsre']['incident_number'].values):
    # print(i)
    temp = {'incident_number':None, 'created_at':None, 'alert_identifier':None, 'node_name':None, 'service':None, 'metric_value':None, 'description':None, 'alert_condition':None}
    try:
        val = ('alertname' not in (df_dict['fsre']['first_trigger_log_entry.channel.cef_details.details.firing'].iloc[i].split('\n')[1].split('=')[0].lower()))
        if (not val):
            firing = df_dict['fsre']['first_trigger_log_entry.channel.cef_details.details.firing'].iloc[i].split('\n')
            temp['incident_number'] = (inc_num)
            temp['created_at'] = (df_dict['fsre']['created_at'].iloc[i])
            temp['alert_identifier']  = (df_dict['fsre']['first_trigger_log_entry.channel.cef_details.details.firing'].iloc[i].split('\n')[1].split('=')[1].lower())
            temp['node_name'] = (temp['alert_identifier'])
            temp['service'] = (df_dict['fsre']['first_trigger_log_entry.service.summary'].iloc[i])
            count = 0
            flag1 = True
            flag2 = True
            for j in firing:
                if 'metric_value' in j and count < 2:
                    count += 1
                    temp['metric_value'] = (j.split('=')[1])
                    flag1 = False
                if 'alertcondition' in j and count < 2:
                    count += 1
                    temp['alert_condition'] = (j.split('=')[1])
                    flag2 = False
            if flag1:
                temp['metric_value'] = ('NA')
            if flag2:
                temp['alert_condition'] = ('NA')
            temp['description'] = (df_dict['fsre']['first_trigger_log_entry.event_details.description'].iloc[i])
    except:
        print(i, inc_num, df_dict['fsre']['title'].iloc[i].lower())
    flag = True
    for e in temp:
        if temp[e] is None:
            flag = False
            break
    if flag:
        for e in temp:
            parsed_dict['fsre'][e].append(temp[e])
# Out:
# 0 1171775 alert received for govprod
# 1 1171774 alert received for govprod
# 2 1169150 alert received for govprod
# 3 1168887 alert received for govprod
# 4 1189584 alert received for govprod
# 5 1092661 alert received for govprod
# 6 1176763 alert received for govprod
# 7 1072745 alert received for govprod
# 8 1072426 alert received for govprod
# 9 1072427 alert received for govprod
# 10 1072428 alert received for govprod
# 11 1072401 alert received for govprod
# 12 1072399 alert received for govprod
# 13 1072400 alert received for govprod
# 14 1072395 alert received for govprod
# 15 1072393 alert received for govprod
# 16 1072394 alert received for govprod
# 17 1072387 alert received for govprod
# 18 1072388 alert received for govprod
# 19 1072389 alert received for govprod
# 20 1071708 alert received for govprod
# 21 1060740 alert received for govprod
# 22 1060741 alert received for govprod
# 23 1060742 alert received for govprod
# 24 1060743 alert received for govprod
# 25 1060294 alert received for govprod
# 26 1060017 alert received for govprod
# 27 1059651 alert received for govprod
# 28 839236 alert received for govprod
# 29 785315 [firing:1] app_synthetic_transaction_api_alert gov-stage app-b2.in.na1dc1.adobesignstage.us app (b azure-na1dc1 true sev1 true core app)
# 33 785282 [firing:1] jms_diagnostic_failing_alert gov-stage app-b1.in.na1dc1.adobesignstage.us adc (b azure-na1dc1 true sev2 true core app)
# 34 785281 [firing:1] jms_diagnostic_failing_alert gov-stage app-b2.in.na1dc1.adobesignstage.us adc (b azure-na1dc1 true sev2 true core app)
# 35 785280 [firing:1] quartz_queue_stalled_by_state_alert gov-stage db1.in.na1dc1.adobesignstage.us mysql (azure-na1dc1 true sev2 true core appdb)
# 36 785272 [firing:1] cds_certifications_last_15_mins_alert gov-stage cds-a1.in.na1dc1.adobesignstage.us cds (a azure-na1dc1 true sev2 true core cds)
# 37 785271 [firing:1] cds_certifications_last_15_mins_alert gov-stage cds-a2.in.na1dc1.adobesignstage.us cds (a azure-na1dc1 true sev2 true core cds)
# 38 785265 [firing:1] high_cds_not_doing_certification_alert gov-stage cds-a2.in.na1dc1.adobesignstage.us cds (a azure-na1dc1 true sev2 true core cds)
# 39 785266 [firing:1] high_cds_not_doing_certification_alert gov-stage cds-a1.in.na1dc1.adobesignstage.us cds (a azure-na1dc1 true sev2 true core cds)
# 52 816917 alert received for govprod
# 53 816908 alert received for govprod
# 54 816885 alert received for govprod
# 55 816874 alert received for govprod
# 56 1450263 alert received for govprod
# 57 1270403 alert received for govprod
# 58 1270402 alert received for govprod
# 59 1270396 alert received for govprod
# 60 1195891 alert received for govprod
# 61 1440888 alert received for govprod
# 62 1440871 alert received for govprod
# 63 1194337 alert received for govprod
# 64 1194339 alert received for govprod
# 65 1194338 alert received for govprod
# 66 848550 alert received for govprod
# 67 848551 alert received for govprod
# 68 848547 alert received for govprod
# 69 848548 alert received for govprod
# 70 848534 alert received for govprod
# 71 848533 alert received for govprod
# 72 1199114 alert received for govprod
# 73 1199115 alert received for govprod
# 74 1199116 alert received for govprod
# 75 1199117 alert received for govprod
# 76 1199118 alert received for govprod
# 77 1199119 alert received for govprod
# 78 1199104 alert received for govprod
# 79 1199103 alert received for govprod
# 80 1199098 alert received for govprod
# 81 1199099 alert received for govprod
# 82 1199094 alert received for govprod
# 83 1199089 alert received for govprod
# 84 1199087 alert received for govprod
# 85 1199088 alert received for govprod
# 86 1199086 alert received for govprod
# 87 1198150 alert received for govprod
# 88 1197958 alert received for govprod
# 89 1054346 alert received for govprod
# 90 1213032 alert received for govprod
# 91 1213029 alert received for govprod
# 92 1213030 alert received for govprod
# 93 1213026 alert received for govprod
# 94 1213027 alert received for govprod
# 95 1213028 alert received for govprod
# 96 1213025 alert received for govprod
# 97 1213021 alert received for govprod
# 98 1213022 alert received for govprod
# 99 1213023 alert received for govprod
# 100 1213024 alert received for govprod
# 101 1213020 alert received for govprod
# 102 1213019 alert received for govprod
# 103 1213016 alert received for govprod
# 104 1213018 alert received for govprod
# 105 1213017 alert received for govprod
# 106 1213015 alert received for govprod
# 107 1213011 alert received for govprod
# 108 1213012 alert received for govprod
# 109 1213013 alert received for govprod
# 110 1213010 alert received for govprod
# 111 1213008 alert received for govprod
# 112 1213005 alert received for govprod
# 113 1213006 alert received for govprod
# 114 1213007 alert received for govprod
# 1173 1044106 alert received for govprod
# 1174 1044105 alert received for govprod
# 1175 1043613 alert received for govprod
# 1176 1043614 alert received for govprod
# 1177 1043594 alert received for govprod

# %%
try:
    pd.DataFrame(parsed_dict['fsre'])
    print('Parsing did well')
    print('Parsed', len(parsed_dict['fsre']['incident_number']), 'alerts')
except:
    print('Not all arrays of same size')
# Out:
# Parsing did well
# Parsed 18 alerts

# %% [markdown]
# ## Pingdom

# %%
parsed_dict['pgdm'] = {'incident_number':[], 'created_at':[], 'alert_identifier':[], 'node_name':[], 'service':[], 'metric_value':[], 'description':[], 'alert_condition':[]}
for i, inc_num in enumerate(df_dict['pgdm']['incident_number'].values):
    # print(i)
    temp = {'incident_number':None, 'created_at':None, 'alert_identifier':None, 'node_name':None, 'service':None, 'metric_value':None, 'description':None, 'alert_condition':None}
    try:
        val = ('pingdom' not in (df_dict['pgdm']['first_trigger_log_entry.channel.cef_details.message'].iloc[i].lower()))
        if (not val):
            temp['service'] = (df_dict['pgdm']['first_trigger_log_entry.service.summary'].iloc[i])
            
            temp['metric_value'] = ('NA')
            
            temp['description'] = (df_dict['pgdm']['first_trigger_log_entry.event_details.description'].iloc[i])
            
            temp['alert_condition'] = (df_dict['pgdm']['first_trigger_log_entry.channel.details.long_description'].iloc[i])
            
            temp['incident_number'] = (inc_num)
            temp['created_at'] = (df_dict['pgdm']['created_at'].iloc[i])
            
            rem_string = ''
            for j in df_dict['pgdm']['first_trigger_log_entry.channel.cef_details.message'].iloc[i].split('-')[1:]:
                rem_string = rem_string + j
            # print(rem_string)
            # + ' in ' +  df_dict['pgdm']['first_trigger_log_entry.channel.details.full_url'].iloc[i] + df_dict['pgdm']['first_trigger_log_entry.channel.cef_details.message'].iloc[i].split('-')[1:])
            temp['alert_identifier'] = (df_dict['pgdm']['first_trigger_log_entry.channel.cef_details.message'].iloc[i].split('-')[0] + ' in ' +  df_dict['pgdm']['first_trigger_log_entry.channel.details.full_url'].iloc[i] + rem_string)
            temp['node_name'] = (df_dict['pgdm']['first_trigger_log_entry.channel.cef_details.message'].iloc[i].split('-')[0] + df_dict['pgdm']['first_trigger_log_entry.channel.cef_details.message'].iloc[i].split('-')[1])
        else:
            print(df_dict['pgdm']['first_trigger_log_entry.channel.cef_details.message'].iloc[i].lower())
    except:
        print(i, inc_num, df_dict['pgdm']['first_trigger_log_entry.channel.cef_details.message'].iloc[i].lower())
    flag = True
    for e in temp:
        if temp[e] is None:
            flag = False
            break
    if flag:
        for e in temp:
            parsed_dict['pgdm'][e].append(temp[e])

# %%
try:
    pd.DataFrame(parsed_dict['pgdm'])
    print('Parsing did well')
    print('Parsed', len(parsed_dict['pgdm']['incident_number']), 'alerts')
except:
    print('Not all arrays of same size')
# Out:
# Parsing did well
# Parsed 1098 alerts

# %% [markdown]
# ## Splunk

# %%
parsed_dict['splunk'] = {'incident_number':[], 'created_at':[], 'alert_identifier':[], 'node_name':[], 'service':[], 'metric_value':[], 'description':[], 'alert_condition':[]}
for i, inc_num in enumerate(df_dict['splunk']['incident_number'].values):
    # print(i)
    temp = {'incident_number':None, 'created_at':None, 'alert_identifier':None, 'node_name':None, 'service':None, 'metric_value':None, 'description':None, 'alert_condition':None}
    try:
        # val = ('alertname' not in (df_dict['splunk']['first_trigger_log_entry.channel.cef_details.details.firing'].iloc[i].split('\n')[1].split('=')[0].lower()))
        # if (not val):
        temp['incident_number']=(inc_num)
        # print('hey')
        temp['created_at']=(df_dict['splunk']['created_at'].iloc[i])
        # print('ho')
        temp['alert_identifier']=(df_dict['splunk']['title'].iloc[i])
        temp['node_name']=(temp['alert_identifier'])
        temp['service']=(df_dict['splunk']['first_trigger_log_entry.service.summary'].iloc[i])
        temp['metric_value']=('NA')
        temp['description']=(df_dict['splunk']['first_trigger_log_entry.event_details.description'].iloc[i])
        temp['alert_condition']=('NA')
    except:
        print(i, inc_num, df_dict['splunk']['title'].iloc[i].lower())
    
    flag = True
    for e in temp:
        if temp[e] is None:
            flag = False
            break
    if flag:
        for e in temp:
            parsed_dict['splunk'][e].append(temp[e])

# %%
try:
    pd.DataFrame(parsed_dict['splunk'])
    print('Parsing did well')
    print('Parsed', len(parsed_dict['splunk']['incident_number']), 'alerts')
except:
    print('Not all arrays of same size')
# Out:
# Parsing did well
# Parsed 2827 alerts

# %% [markdown]
# ## Datadog

# %%
parsed_dict['ddg'] = {'incident_number':[], 'created_at':[], 'alert_identifier':[], 'node_name':[], 'service':[], 'metric_value':[], 'description':[], 'alert_condition':[]}
count = 0
for i, inc_num in enumerate(df_dict['ddg']['incident_number'].values):
    temp = {'incident_number':None, 'created_at':None, 'alert_identifier':None, 'node_name':None, 'service':None, 'metric_value':None, 'description':None, 'alert_condition':None}
    check = False
    try:
        if ('prod' in df_dict['ddg']['title'].iloc[i].lower()):
            try:
                ls = list(map(str.strip,df_dict['ddg']['title'].iloc[i].lower().split('-')))
                ind = ls.index('prod') + 1
                rem_string = ''
                for j in range(ind,len(ls)):
                    rem_string += ls[j] + ' '
                # print(rem_string)
                flag = True
            except:
                print(i,inc_num, 'prod nhi mila',df_dict['ddg']['title'].iloc[i])
                flag = False
            if flag:
                temp['alert_identifier']=(rem_string)
                temp['incident_number']=(inc_num)
                temp['created_at']=(df_dict['ddg']['created_at'].iloc[i])
                temp['description']=(df_dict['ddg']['first_trigger_log_entry.channel.description'].iloc[i])
                temp['service']=(df_dict['ddg']['first_trigger_log_entry.service.summary'].iloc[i])
                if (' on ' not in temp['alert_identifier'] and ' for ' not in temp['alert_identifier'] and flag):
                    temp['node_name']=(ls[ind])
                else:
                    if(' on ' in temp['alert_identifier']):
                        ind = temp['alert_identifier'].find(' on ')
                        temp['node_name'] = (temp['alert_identifier'][:ind])
                    else:
                        if(' for ' in temp['alert_identifier']):
                            ind = temp['alert_identifier'].find(' for ')
                            temp['node_name']=(temp['alert_identifier'][:ind])
                metric_text = df_dict['ddg']['first_trigger_log_entry.channel.details.body'].iloc[i].lower().split('\n')
                # print(metric_text, '\n')
                check = True
                try:
                    for j in metric_text:
                        if 'metric value' in j:
                            check = False
                            temp['metric_value']=(j.split(':')[1])
                    temp['alert_condition']=(metric_text[2])
                except:
                    count += 1
                    temp['metric_value']=('NA')
                    temp['alert_condition']=('NA')
                if check:
                    print(i, inc_num, metric_text)
        else:
            print(i,'prod hi nhi')
        # val = ('alertname' not in (df_dict['dba']['first_trigger_log_entry.channel.cef_details.details.firing'].iloc[i].split('\n')[1].split('=')[0].lower()))
        # if (not val):
        #     parsed_dict['dba']['incident_number'].append(inc_num)
        #     # print('hey')
        #     parsed_dict['dba']['created_at'].append(df_dict['dba']['created_at'].iloc[i])
        #     # print('ho')
        #     parsed_dict['dba']['alert_identifier'].append(df_dict['dba']['first_trigger_log_entry.channel.cef_details.details.firing'].iloc[i].split('\n')[1].split('=')[1].lower())
        #     parsed_dict['dba']['node_name'].append(parsed_dict['dba']['alert_identifier'][-1])
    except Exception as e:
        if check:
            print('yes', metric_text)
        print(i, inc_num, df_dict['ddg']['title'].iloc[i].lower())
        
    flag = True
    for e in temp:
        if temp[e] is None:
            flag = False
            break
    if flag:
        for e in temp:
            parsed_dict['ddg'][e].append(temp[e])
# Out:
# 360 530963 ['tungsten connector process is down for isc-a1.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 4 processes found for tungsten_connector']
# 361 530960 ['tomcat catalina process is down for app-b4.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 364 530858 ['tungsten connector process is down for isc-b6.in.na4dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 5 processes found for tungsten_connector']
# 368 530729 ['tomcat catalina process is down for app-b4.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 369 530724 ['tomcat catalina process is down for app-b12.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 370 530628 ['splunk service is down for bclconvert-a1.in.na3dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod']
# 371 530627 ['splunk service is down for bclconvert-a2.in.na3dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod']
# 372 530626 ['splunk service is down for bclconvert-a1.in.eu2dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod']
# 373 530625 ['splunk service is down for bclconvert-a3.in.eu2dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod']
# 374 530624 ['splunk service is down for bclconvert-a3.in.na3dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod']
# 375 530623 ['splunk service is down for bclconvert-a2.in.eu2dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod']
# 377 530541 ['tomcat catalina process is down for app-a23.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 378 530501 ['hubble agent is down for apache2.in.na1dc1.echosignsandbox.com @slack-adobesignmainapp-sign-alerts-sandbox-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for hubble']
# 379 530500 ['process apache httpd is down for apache2.in.na1dc1.echosignsandbox.com @slack-adobesignmainapp-sign-alerts-sandbox-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for apache_httpd']
# 380 530496 ['hubble agent is down for apache3.in.na1dc1.echosignsandbox.com @slack-adobesignmainapp-sign-alerts-sandbox-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for hubble']
# 381 530493 ['process apache httpd is down for apache3.in.na1dc1.echosignsandbox.com @slack-adobesignmainapp-sign-alerts-sandbox-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for apache_httpd']
# 398 202853 ['tomcat catalina process is down for app-a21.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 2 processes found for apache_catalina']
# 399 202846 ['tomcat catalina process is down for app-a11.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 401 202833 ['tomcat catalina process is down for app-a15.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 581 350890 ['event consumer application-jmsapp process is down for event-a2.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for eventconsumer']
# 582 350887 ['tomcat catalina process is down for app-a18.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 598 350814 ['tomcat catalina process is down for app-a2.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 2 processes found for apache_catalina']
# 602 350743 ['event consumer application-jmsapp process is down for event-a9.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 2 processes found for eventconsumer']
# 631 350607 ['hubble agent is down for dmzabastion1.in.au1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for hubble']
# 638 391863 ['quartz jobs application-jobs process is down for job-b2.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for job']
# 647 391407 ['tomcat catalina process is down for app-a4.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 648 391371 ['tomcat catalina process is down for app-a24.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 649 391313 ['tomcat catalina process is down for app-a17.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 650 391216 ['tomcat catalina process is down for app-a1.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 776 489748 ['process apache httpd is down for www3.in.na4dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 777 489747 ['process apache httpd is down for www3.in.na2dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 778 489746 ['process apache httpd is down for www2.in.na4dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 779 489743 ['process apache httpd is down for www1.in.na4dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 780 489735 ['process apache httpd is down for www1.in.eu1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 879 67858 ['tomcat catalina process is down for app-b7.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for apache_catalina']
# 885 63532 ['tomcat catalina process is down for app-a1.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for apache_catalina']
# 901 50318 ['quartz jobs application-jobs process is down for job-b2.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for job']
# 914 49386 ['quartz jobs application-jobs process is down for job-b1.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for job']
# 936 45463 ['quartz jobs application-jobs process is down for job-b2.in.in1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for job']
# 1029 403687 ['tomcat catalina process is down for app-a7.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 2 processes found for apache_catalina']
# 1030 403666 ['tomcat catalina process is down for app-a3.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1031 403650 ['tomcat catalina process is down for app-a23.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1032 403632 ['tomcat catalina process is down for app-a16.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1033 403564 ['tomcat catalina process is down for app-a5.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1081 514902 ['process apache httpd is down for www2.in.jp1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 1082 514892 ['process apache httpd is down for www1.in.jp1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 1085 514841 ['event consumer application-jmsapp process is down for event-a1.in.jp1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for eventconsumer']
# 1096 514818 ['tungsten connector process is down for app-a2.in.jp1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for tungsten_connector']
# 1097 514817 ['tomcat catalina process is down for app-a2.in.jp1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1101 514810 ['event consumer application-jmsapp process is down for event-a3.in.jp1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for eventconsumer']
# 1106 514637 ['tomcat catalina process is down for app-b24.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1107 514634 ['tomcat catalina process is down for app-b22.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1108 514628 ['tomcat catalina process is down for app-b6.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1110 514619 ['tomcat catalina process is down for app-a4.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1116 514376 ['tomcat catalina process is down for app-b11.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1155 410522 ['tomcat catalina process is down for app-b23.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1190 432613 ['tomcat catalina process is down for app-b23.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1191 432610 ['tomcat catalina process is down for app-b13.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1192 432608 ['tomcat catalina process is down for app-b10.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1193 432605 ['tomcat catalina process is down for app-b1.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1243 494121 ['tomcat catalina process is down for app-a11.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1244 494118 ['tomcat catalina process is down for app-a20.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1245 494116 ['tomcat catalina process is down for app-a19.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1247 494113 ['tomcat catalina process is down for app-a12.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1248 494099 ['event consumer application-jmsapp process is down for event-b3.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for eventconsumer']
# 1264 493980 ['process qpid is down for qpid-b2.in.in1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for qpid']
# 1366 503774 ['quartz jobs application-jobs process is down for job-b2.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 2 processes found for job']
# 1385 503441 ['tomcat catalina process is down for app-a11.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1388 503428 ['tomcat catalina process is down for app-a17.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1408 509948 ['tomcat catalina process is down for app-a5.in.eu2dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 2 processes found for apache_catalina']
# 1409 509946 ['tomcat catalina process is down for app-a5.in.eu2dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 2 processes found for apache_catalina']
# 1418 509928 ['hubble agent is down for apache3.in.eu2dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for hubble']
# 1425 509563 ['tomcat catalina process is down for app-b13.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1426 509557 ['tomcat catalina process is down for app-b5.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1427 509555 ['tomcat catalina process is down for app-b4.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1429 509551 ['tomcat catalina process is down for app-a11.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1430 509549 ['tomcat catalina process is down for app-a9.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1431 509546 ['tomcat catalina process is down for app-a6.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1433 509543 ['tomcat catalina process is down for app-a3.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1434 509541 ['tomcat catalina process is down for app-a1.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1442 509484 ['splunk service is down for bclconvert-a1.in.na3dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod']
# 1443 509483 ['splunk service is down for bclconvert-a3.in.na3dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod']
# 1465 509322 ['quartz jobs application-jobs process is down for job-a2.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for job']
# 1471 509189 ['the java process for a linuxtaskworker instance is not running on wordformifier-a1.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for taskworker']
# 1505 554401 ['tungsten connector process is down for isc-a3.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 5 processes found for tungsten_connector']
# 1527 498709 ['process apache httpd is down for www2.in.eu2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 1547 497849 ['tomcat catalina process is down for checkout-a1.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1548 497848 ['tomcat catalina process is down for checkout-a2.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1549 497847 ['tomcat catalina process is down for checkout-a3.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1550 497821 ['tomcat catalina process is down for app-a10.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1551 497816 ['tomcat catalina process is down for app-a15.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1584 497375 ['process apache httpd is down for freshclam3.in.na3dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 1601 497236 ['tungsten connector process is down for app-b15.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for tungsten_connector']
# 1602 497235 ['tomcat catalina process is down for app-b15.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1709 15304 prod nhi mila SignProd_SyntheticTransaction_CSO
# 1710 15303 prod nhi mila SignProd_SyntheticTransaction_CSO
# 1711 15302 prod nhi mila SignProd_SyntheticTransaction_CSO
# 1712 15301 prod nhi mila SignProd_SyntheticTransaction_CSO
# 1713 15300 prod nhi mila SignProd_SyntheticTransaction_CSO
# 1714 15299 prod nhi mila SignProd_SyntheticTransaction_CSO
# 1715 15298 prod nhi mila SignProd_SyntheticTransaction_CSO
# 1716 15297 prod nhi mila SignProd_SyntheticTransaction_CSO
# 1717 15296 prod nhi mila SignProd_SyntheticTransaction_CSO
# 1746 15145 ['event consumer application-jmsapp process is down for event-b4.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 2 processes found for eventconsumer']
# 1772 15102 prod nhi mila SignProd_SyntheticTransaction_CSO
# 1773 15101 prod nhi mila SignProd_SyntheticTransaction_CSO
# 1774 15078 ['process qpid is down for qpid-a3.in.in1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for qpid']
# 1779 15046 ['hubble agent is down for qpid-b1.in.na3dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for hubble']
# 1780 15045 ['process qpid is down for qpid-b1.in.na3dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for qpid']
# 1788 27046 ['event consumer application-jmsapp process is down for event-b9.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for eventconsumer']
# 1841 26854 prod nhi mila SignProd_SyntheticTransaction_CSO
# 1850 425745 ['tomcat catalina process is down for app-b2.in.au1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1851 425740 ['tomcat catalina process is down for app-a19.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1864 424812 ['process apache httpd is down for gps-b6.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 1865 424807 ['process apache httpd is down for gps-b3.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 1866 424806 ['tomcat catalina process is down for gps-b3.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1920 30693 ['tomcat catalina process is down for app-b6.in.na3dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for apache_catalina']
# 1921 30660 ['tomcat catalina process is down for app-b6.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for apache_catalina']
# 1928 30646 ['tomcat catalina process is down for app-a23.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for apache_catalina']
# 1941 30476 ['the java process for a rasterpdfadobeworker instance is not running on raster-a22.in.na2dc2.echosign.com and needs to be started or the instance rebuilt. @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for raster']
# 1942 30475 ['the java process for a rasterpdfadobeworker instance is not running on raster-a22.in.na2dc2.echosign.com and needs to be started or the instance rebuilt. @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for raster']
# 1968 490612 ['tomcat catalina process is down for uds-a4.in.useast1.utility.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1969 490611 ['tungsten connector process is down for uds-a1.in.useast1.utility.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for tungsten_connector']
# 1970 490610 ['tungsten connector process is down for uds-a5.in.useast1.utility.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for tungsten_connector']
# 1971 490609 ['tomcat catalina process is down for uds-a6.in.useast1.utility.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1972 490608 ['tungsten connector process is down for uds-a4.in.useast1.utility.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for tungsten_connector']
# 1973 490607 ['tungsten connector process is down for uds-a3.in.useast1.utility.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for tungsten_connector']
# 1974 490606 ['tungsten connector process is down for uds-a2.in.useast1.utility.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for tungsten_connector']
# 1975 490605 ['tomcat catalina process is down for uds-a3.in.useast1.utility.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1976 490604 ['tomcat catalina process is down for uds-a5.in.useast1.utility.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1977 490603 ['tungsten connector process is down for uds-a6.in.useast1.utility.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for tungsten_connector']
# 1978 490602 ['tomcat catalina process is down for uds-a2.in.useast1.utility.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1979 490601 ['tomcat catalina process is down for uds-a1.in.useast1.utility.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 1990 490492 ['process apache httpd is down for www2.in.in1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 1993 490486 ['process apache httpd is down for www3.in.au1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 1994 490485 ['process apache httpd is down for www1.in.in1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 1995 490479 ['process apache httpd is down for www2.in.au1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 1996 490478 ['process apache httpd is down for www2.in.jp1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 1997 490472 ['process apache httpd is down for www1.in.jp1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 1998 490468 ['process apache httpd is down for www3.in.na4dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 1999 490467 ['process apache httpd is down for www3.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 2000 490464 ['process apache httpd is down for www2.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 2001 490461 ['process apache httpd is down for www1.in.na4dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 2002 490460 ['process apache httpd is down for www1.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 2003 490455 ['process apache httpd is down for www3.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 2004 490452 ['event consumer application-jmsapp process is down for event-b10.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 3 processes found for eventconsumer']
# 2005 490448 ['process apache httpd is down for www2.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 2006 490441 ['process apache httpd is down for www1.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 2033 32218 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2034 32215 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2035 32216 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2036 32213 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2037 32214 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2038 32212 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2039 32211 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2040 32210 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2041 32209 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2042 32208 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2043 32207 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2044 32206 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2045 32205 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2046 32204 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2047 32203 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2048 32202 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2049 32201 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2050 32200 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2051 32199 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2052 32198 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2053 32197 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2054 32196 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2055 32195 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2056 32194 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2057 32193 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2058 32192 prod nhi mila SignProd_SyntheticTransaction_CSO
# 2151 468512 ['quartz jobs application-jobs process is down for job-a1.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for job']
# 2159 468470 ['quartz jobs application-jobs process is down for job-b2.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for job']
# 2173 468289 ['the java process for a linuxtaskworker instance is not running on wordformifier-b1.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for taskworker']
# 2177 468248 ['tomcat catalina process is down for app-b25.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2179 468245 ['tomcat catalina process is down for app-b10.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2217 467028 ['tomcat catalina process is down for app-b23.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2218 467018 ['tomcat catalina process is down for app-b1.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2219 466978 ['tomcat catalina process is down for app-b7.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2253 453319 ['event consumer application-jmsapp process is down for event-b3.in.na3dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for eventconsumer']
# 2255 453277 ['the java process for a rasterpdfadobeworker instance is not running on raster-a16.in.na2dc2.echosign.com and needs to be started or the instance rebuilt. @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 2 processes found for raster']
# 2279 453100 ['tomcat catalina process is down for app-a24.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2280 453099 ['tomcat catalina process is down for app-a21.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2281 453098 ['tungsten connector process is down for app-a21.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for tungsten_connector']
# 2282 453097 ['tungsten connector process is down for app-a24.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for tungsten_connector']
# 2283 453095 ['tungsten connector process is down for isc-a4.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for tungsten_connector']
# 2284 453094 ['tomcat catalina process is down for isc-a4.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2286 453082 ['splunk service is down for bclconvert-b1.in.na3dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod']
# 2287 453081 ['splunk service is down for bclconvert-b2.in.na3dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod']
# 2354 441507 ['tomcat catalina process is down for app-a24.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2374 441208 ['tomcat catalina process is down for app-b1.in.eu2dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2402 492479 ['tomcat catalina process is down for app-a9.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2404 492474 ['tomcat catalina process is down for app-a5.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2407 492467 ['tomcat catalina process is down for app-a2.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2415 492429 ['tomcat catalina process is down for app-b9.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2418 492323 ['tomcat catalina process is down for app-b3.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2419 492320 ['tomcat catalina process is down for app-b2.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2442 492161 ['event consumer application-jmsapp process is down for event-a3.in.in1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for eventconsumer']
# 2450 491911 ['tomcat catalina process is down for app-a2.in.au1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 2 processes found for apache_catalina']
# 2458 491837 ['tomcat catalina process is down for app-b6.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2505 549358 ['tomcat catalina process is down for app-a7.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2514 549298 ['tomcat catalina process is down for app-b5.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2515 549296 ['tomcat catalina process is down for app-b1.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2517 549294 ['tomcat catalina process is down for app-b23.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2519 549288 ['tomcat catalina process is down for app-b13.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2520 503281 ['tomcat catalina process is down for app-a17.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2522 503271 ['tomcat catalina process is down for app-a11.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2530 503196 ['tomcat catalina process is down for app-b8.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2545 503004 ['tomcat catalina process is down for app-a5.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2549 502996 ['process apache httpd is down for apache5.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 264 processes found for apache_httpd']
# 2559 502982 ['process apache httpd is down for apache4.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 251 processes found for apache_httpd']
# 2585 11373 ['the java process for a linuxtaskworker instance is not running on pdfreader-b3.in.au1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for taskworker']
# 2588 11352 ['the java process for a linuxtaskworker instance is not running on pdfreader-a8.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for taskworker']
# 2601 548061 ['tomcat catalina process is down for app-b2.in.na4dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2602 548029 ['tomcat catalina process is down for app-b8.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2603 548012 ['tomcat catalina process is down for app-a14.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2604 548011 ['tomcat catalina process is down for app-a10.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2614 547869 ['process apache httpd is down for www2.in.na3dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 2621 547750 ['tungsten connector process is down for isc-a3.in.eu2dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 5 processes found for tungsten_connector']
# 2642 547484 ['tomcat catalina process is down for app-b23.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2643 547475 ['tomcat catalina process is down for app-b1.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2644 547470 ['tomcat catalina process is down for app-b10.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2645 547469 ['tomcat catalina process is down for app-b8.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2647 547459 ['tomcat catalina process is down for app-a6.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 2651 547300 ['tungsten connector process is down for isc-a6.in.eu2dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 5 processes found for tungsten_connector']
# 2652 547276 ['tungsten connector process is down for isc-b5.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 5 processes found for tungsten_connector']
# 2653 521912 ['tomcat catalina process is down for app-a5.in.eu2dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 2 processes found for apache_catalina']
# ...
# 16526 475880 ['process apache httpd is down for apache5.in.na4dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 16527 475873 ['process apache httpd is down for apache4.in.na4dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 16530 475863 ['process apache httpd is down for apache2.in.na4dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 16554 395806 ['process qpid is down for qpid-b3.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for qpid']
# 16555 395805 ['process qpid is down for qpid-b2.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for qpid']
# 16557 395786 ['process qpid is down for qpid-b1.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for qpid']
# 16570 392083 ['quartz jobs application-jobs process is down for job-b1.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for job']
# 16571 392019 ['quartz jobs application-jobs process is down for job-b1.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for job']
# 16577 414378 ['tomcat catalina process is down for app-b1.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 16578 414374 ['tomcat catalina process is down for app-b23.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 16579 414356 ['tomcat catalina process is down for app-b5.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 16583 413433 ['process qpid is down for qpid-b1.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for qpid']
# 16609 42802 ['splunk service is down for bclconvert-b1.in.eu2dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod']
# 16611 42181 ['tomcat catalina process is down for app-a11.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for apache_catalina']
# 16614 41034 ['splunk service is down for bclconvert-b1.in.na3dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod']
# 16646 39538 ['the java process for a rasterpdfadobeworker instance is not running on raster-b6.in.na1dc1.echosign.com and needs to be started or the instance rebuilt. @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 2 processes found for raster']
# 16647 39537 ['the java process for a rasterpdfadobeworker instance is not running on raster-b6.in.na1dc1.echosign.com and needs to be started or the instance rebuilt. @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 2 processes found for raster']
# 16671 36697 ['tomcat catalina process is down for app-b24.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for apache_catalina']
# 16959 490168 ['tomcat catalina process is down for app-b11.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17186 511626 ['tomcat catalina process is down for app-b18.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17188 511616 ['tomcat catalina process is down for app-b25.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17190 511569 ['tomcat catalina process is down for app-a2.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17198 511292 ['the java process for a linuxtaskworker instance is not running on wordformifier-b1.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for taskworker']
# 17203 511212 ['tomcat catalina process is down for gps-b1.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17204 511211 ['tomcat catalina process is down for gps-b5.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17205 511210 ['tomcat catalina process is down for gps-b3.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17206 511209 ['tomcat catalina process is down for gps-b4.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17207 511208 ['tomcat catalina process is down for gps-b6.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17208 511207 ['tomcat catalina process is down for gps-b2.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17209 511206 ['process apache httpd is down for gps-b5.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 17210 511205 ['process apache httpd is down for gps-b1.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 17211 511204 ['process apache httpd is down for gps-b4.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 17212 511203 ['process apache httpd is down for gps-b2.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 17213 511202 ['process apache httpd is down for gps-b6.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 17214 511201 ['process apache httpd is down for gps-b3.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_httpd']
# 17218 511109 ['tomcat catalina process is down for cds-a2.in.na3dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17219 511108 ['tomcat catalina process is down for cds-a1.in.na3dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17220 511107 ['tomcat catalina process is down for cds-a3.in.na3dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17221 511106 ['tomcat catalina process is down for cds-a3.in.na4dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17222 511105 ['tomcat catalina process is down for cds-a2.in.au1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17223 511104 ['tomcat catalina process is down for cds-a3.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17224 511103 ['tomcat catalina process is down for cds-a1.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17225 511102 ['tomcat catalina process is down for cds-a1.in.jp1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17226 511101 ['tomcat catalina process is down for cds-a2.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17227 511100 ['tomcat catalina process is down for cds-a2.in.in1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17228 511099 ['tomcat catalina process is down for cds-a2.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17229 511098 ['tomcat catalina process is down for cds-a1.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17230 511097 ['tomcat catalina process is down for cds-a2.in.na4dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17231 511096 ['tomcat catalina process is down for cds-a1.in.na4dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17232 511095 ['tomcat catalina process is down for cds-a2.in.jp1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17233 511094 ['tomcat catalina process is down for cds-a1.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17234 511093 ['tomcat catalina process is down for cds-a3.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17235 511092 ['tomcat catalina process is down for cds-a1.in.in1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17236 511091 ['tomcat catalina process is down for cds-a2.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17237 511090 ['tomcat catalina process is down for cds-a3.in.au1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17238 511089 ['tomcat catalina process is down for cds-a1.in.au1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17240 510870 ['the java process for a rasterpdfadobeworker instance is not running on raster-a12.in.eu1dc2.echosign.com and needs to be started or the instance rebuilt. @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 2 processes found for raster']
# 17244 510711 ['tomcat catalina process is down for app-b18.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17245 510708 ['tomcat catalina process is down for app-b14.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17246 510707 ['tomcat catalina process is down for app-b5.in.na2dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17247 510702 ['tomcat catalina process is down for app-b15.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17248 510697 ['tomcat catalina process is down for app-b5.in.na1dc1.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17249 510689 ['tomcat catalina process is down for app-a5.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17250 510686 ['tomcat catalina process is down for app-a4.in.eu1dc2.echosign.com @slack-adobesignmainapp-sign-alerts-prod  @pagerduty-datadog-prod   @webhook-haas_adobesign_datadog_alert', '', 'procs critical: 0 processes found for apache_catalina']
# 17254 510264 ['process qpid is down for qpid-b2.in.na1dc1.echosignsandbox.com @slack-adobesignmainapp-sign-alerts-sandbox-prod  @pagerduty-datadog-prod  ', '', 'procs critical: 0 processes found for qpid']

# %%
try:
    pd.DataFrame(parsed_dict['ddg'])
    print('Parsing did well')
    print('Parsed', len(parsed_dict['ddg']['incident_number']), 'alerts')
except:
    print('Not all arrays of same size')
# Out:
# Parsing did well
# Parsed 15348 alerts

# %% [markdown]
# ## EDA

# %%
parsed_dict['eda'] = {'incident_number':[], 'created_at':[], 'alert_identifier':[], 'node_name':[], 'service':[], 'metric_value':[], 'description':[], 'alert_condition':[]}
for i, inc_num in enumerate(df_dict['eda']['incident_number'].values):
    temp = {'incident_number':None, 'created_at':None, 'alert_identifier':None, 'node_name':None, 'service':None, 'metric_value':None, 'description':None, 'alert_condition':None}
    temp['incident_number'] = (inc_num)
    temp['created_at'] = (df_dict['eda']['created_at'].iloc[i])
    if ('eda' in df_dict['eda']['title'].iloc[i].lower()):
        temp['alert_identifier'] = (df_dict['eda']['title'].iloc[i])
        temp['node_name'] = ('EDA ' + df_dict['eda']['title'].iloc[i].split(':')[1])
    else:
        temp['alert_identifier'] = (df_dict['eda']['title'].iloc[i].split(',')[0])
        temp['node_name'] = (df_dict['eda']['title'].iloc[i].split(',')[0])
    temp['service'] = df_dict['eda']['first_trigger_log_entry.service.summary'].iloc[i]
    temp['metric_value'] = 'NA'
    temp['description'] = 'NA'
    temp['alert_condition'] = 'NA'
    
    flag = True
    for e in temp:
        if temp[e] is None:
            flag = False
            break
    if flag:
        for e in temp:
            parsed_dict['eda'][e].append(temp[e])

# %%
try:
    pd.DataFrame(parsed_dict['eda'])
    print('Parsing did well')
    print('Parsed', len(parsed_dict['eda']['incident_number']), 'alerts')
except:
    print('Not all arrays of same size')
# Out:
# Parsing did well
# Parsed 536 alerts

# %% [markdown]
# ## Sign MS Techops On Call

# %%
parsed_dict['smto'] = {'incident_number':[], 'created_at':[], 'alert_identifier':[], 'node_name':[], 'service':[], 'metric_value':[], 'description':[], 'alert_condition':[]}
for i, inc_num in enumerate(df_dict['smto']['incident_number'].values):
    temp = {'incident_number':None, 'created_at':None, 'alert_identifier':None, 'node_name':None, 'service':None, 'metric_value':None, 'description':None, 'alert_condition':None}
    if ('splunk alert' in df_dict['smto']['title'].iloc[i].lower()):
        temp['incident_number']=(inc_num)
        temp['created_at']=(df_dict['smto']['created_at'].iloc[i])
        temp['alert_identifier']=(df_dict['smto']['title'].iloc[i])
        temp['node_name']=('Splunk Alert ' + df_dict['smto']['title'].iloc[i].split(':')[1])
        temp['service'] = df_dict['smto']['first_trigger_log_entry.service.summary'].iloc[i]
        temp['metric_value'] = 'NA'
        temp['description'] = 'NA'
        temp['alert_condition'] = 'NA'
        
    flag = True
    for e in temp:
        if temp[e] is None:
            flag = False
            break
    if flag:
        for e in temp:
            parsed_dict['smto'][e].append(temp[e])

# %%
try:
    pd.DataFrame(parsed_dict['pgdm'])
    print('Parsing did well')
    print('Parsed', len(parsed_dict['smto']['incident_number']), 'alerts')
except:
    print('Not all arrays of same size')
# Out:
# Parsing did well
# Parsed 166 alerts

# %% [markdown]
# ## Merging All

# %%
parsed_merged = {'incident_number':[], 'created_at':[], 'alert_identifier':[], 'node_name':[], 'metric_value':[], 'service':[], 'description':[], 'alert_condition':[]}
service_final = ['sre', 'dba' , 'fsre' , 'splunk' , 'pgdm', 'eda', 'ddg', 'smto']
for service in service_final:
    for key in parsed_merged:
        parsed_merged[key] = parsed_merged[key] + parsed_dict[service][key]
parsed_merged['alert_identifier'] = list(map(str.strip, parsed_merged['alert_identifier']))
parsed_merged['node_name'] = list(map(str.strip, parsed_merged['node_name']))

# %% [markdown]
# ## Finding Unique alerts and creating a Mapping

# %%
uniq_alerts = list(set(parsed_merged['node_name']))      ## order remains the same

# %%
len(uniq_alerts)
# Out:
# 937

# %%
alerts_df_dict = {'alert_name':[], 'id':[]}
for i, alert in enumerate (uniq_alerts):
    alerts_df_dict['alert_name'].append(alert)
    alerts_df_dict['id'].append(i)
pd.DataFrame(alerts_df_dict).to_csv('./Alerts_data/alert_id_mapping.csv')

# %%
alert_df = pd.read_csv('./Alerts_data/alert_id_mapping.csv')
alerts_mapping = {}
for i, alert in enumerate (alert_df['alert_name'].values):
    alerts_mapping[alert] = i

# %%
parsed_merged['alert_id'] = []
for i,alert in enumerate(parsed_merged['node_name']):
    parsed_merged['alert_id'].append(alerts_mapping[alert])

parsed_merged_df = pd.DataFrame(parsed_merged)
parsed_merged_df.to_csv('./Alerts_data/all_alerts_parsed.csv')
parsed_merged_df.head()
# Out:
#   incident_number            created_at  \
# 0          635303  2021-08-18T03:18:20Z
# 1          635155  2021-08-18T01:25:51Z
# 2          635137  2021-08-18T01:12:02Z
# 3          635061  2021-08-18T00:23:49Z
# 4          634681  2021-08-17T19:25:49Z
#
#                                     alert_identifier  \
# 0              instance_disk_volume_usage_high_alert
# 1  high_qpid_queuesize_failed_callbackoutboundeve...
# 2  high_qpid_oldestmessageage_workflowsignatureq_...
# 3  high_qpid_oldestmessageage_agreementexpiration...
# 4  high_qpid_queuesize_agreementeventpropagationq...
#
#                                            node_name        metric_value  \
# 0              instance_disk_volume_usage_high_alert   90.50473822274459
# 1  high_qpid_queuesize_failed_callbackoutboundeve...                4177
# 2  high_qpid_oldestmessageage_workflowsignatureq_...              643673
# 3  high_qpid_oldestmessageage_agreementexpiration...              651633
# 4  high_qpid_queuesize_agreementeventpropagationq...                 707
#
#           service                                        description  \
# 0  Adobe Sign SRE  [FIRING:1] instance_disk_volume_usage_high_ale...
# 1  Adobe Sign SRE  [FIRING:1] high_qpid_queuesize_failed_callback...
# 2  Adobe Sign SRE  [FIRING:1] high_qpid_oldestmessageage_workflow...
# 3  Adobe Sign SRE  [FIRING:1] high_qpid_oldestmessageage_agreemen...
# 4  Adobe Sign SRE  [FIRING:1] high_qpid_queuesize_agreementeventp...
#
#                                      alert_condition  alert_id
# 0   (100 - (sum(node_filesystem_avail_bytes{tiern...       726
# 1              min(qpid_queuedepthmessages{queuename       833
# 2                min(qpid_oldestmessageage{queuename       612
# 3                min(qpid_oldestmessageage{queuename       871
# 4              min(qpid_queuedepthmessages{queuename       163
